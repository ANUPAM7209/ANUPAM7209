# %% [markdown]
# <a href="https://colab.research.google.com/github/ANUPAM7209/ANUPAM7209/blob/main/Objectdetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **See the world through AI**

# %% [markdown]
# Yolo - you only look once

# %%
# !pip install -q ultralytics opencv-python-headless matplotlib pillow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.8 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt
from PIL import  Image
from google.colab import files

# %%
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
print("uploaded:", file_name)
# Out:
#      <input type="file" id="files-85839a63-050a-49f6-8809-034a1b6c7268" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85839a63-050a-49f6-8809-034a1b6c7268">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model = YOLO("yolov8n.pt")

# %%
results = model(file_name)
annotated = results[0].plot()
# Out:
# image 1/1 /content/Screenshot from 2025-09-09 22-12-32.png: 384x640 1 person, 220.4ms
# Speed: 4.3ms preprocess, 220.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
#check the image what we have uploaded and see that live what we have done
plt.figure(figsize=(12,8))
plt.imshow(cv2.cvtColor(annotated,cv2.COLOR_BGR2RGB))
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1079.5), np.float64(-0.5))
